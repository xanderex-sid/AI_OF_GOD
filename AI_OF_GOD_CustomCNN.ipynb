# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/GOD_OF_AI/ai-of-god-v20.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/3880.jpg
#   inflating: train/3881.jpg
#   inflating: train/3882.jpg
#   inflating: train/3883.jpg
#   inflating: train/3884.jpg
#   inflating: train/3885.jpg
#   inflating: train/3886.jpg
#   inflating: train/3887.jpg
#   inflating: train/3888.jpg
#   inflating: train/3889.jpg
#   inflating: train/389.jpg
#   inflating: train/3890.jpg
#   inflating: train/3891.jpg
#   inflating: train/3892.jpg
#   inflating: train/3893.jpg
#   inflating: train/3894.jpg
#   inflating: train/3895.jpg
#   inflating: train/3896.jpg
#   inflating: train/3897.jpg
#   inflating: train/3898.jpg
#   inflating: train/3899.jpg
#   inflating: train/39.jpg
#   inflating: train/390.jpg
#   inflating: train/3900.jpg
#   inflating: train/3901.jpg
#   inflating: train/3902.jpg
#   inflating: train/3903.jpg
#   inflating: train/3904.jpg
#   inflating: train/3905.jpg
#   inflating: train/3906.jpg
#   inflating: train/3907.jpg
#   inflating: train/3908.jpg
#   inflating: train/3909.jpg
#   inflating: train/391.jpg
#   inflating: train/3910.jpg
#   inflating: train/3911.jpg
#   inflating: train/3912.jpg
#   inflating: train/3913.jpg
#   inflating: train/3914.jpg
#   inflating: train/3915.jpg
#   inflating: train/3916.jpg
#   inflating: train/3917.jpg
#   inflating: train/3918.jpg
#   inflating: train/3919.jpg
#   inflating: train/392.jpg
#   inflating: train/3920.jpg
#   inflating: train/3921.jpg
#   inflating: train/3922.jpg
#   inflating: train/3923.jpg
#   inflating: train/3924.jpg
#   inflating: train/3925.jpg
#   inflating: train/3926.jpg
#   inflating: train/3927.jpg
#   inflating: train/3928.jpg
#   inflating: train/3929.jpg
#   inflating: train/393.jpg
#   inflating: train/3930.jpg
#   inflating: train/3931.jpg
#   inflating: train/3932.jpg
#   inflating: train/3933.jpg
#   inflating: train/3934.jpg
#   inflating: train/3935.jpg
#   inflating: train/3936.jpg
#   inflating: train/3937.jpg
#   inflating: train/3938.jpg
#   inflating: train/3939.jpg
#   inflating: train/394.jpg
#   inflating: train/3940.jpg
#   inflating: train/3941.jpg
#   inflating: train/3942.jpg
#   inflating: train/3943.jpg
#   inflating: train/3944.jpg
#   inflating: train/3945.jpg
#   inflating: train/3946.jpg
#   inflating: train/3947.jpg
#   inflating: train/3948.jpg
#   inflating: train/3949.jpg
#   inflating: train/395.jpg
#   inflating: train/3950.jpg
#   inflating: train/3951.jpg
#   inflating: train/3952.jpg
#   inflating: train/3953.jpg
#   inflating: train/3954.jpg
#   inflating: train/3955.jpg
#   inflating: train/3956.jpg
#   inflating: train/3957.jpg
#   inflating: train/3958.jpg
#   inflating: train/3959.jpg
#   inflating: train/396.jpg
#   inflating: train/3960.jpg
#   inflating: train/3961.jpg
#   inflating: train/3962.jpg
#   inflating: train/3963.jpg
#   inflating: train/3964.jpg
#   inflating: train/3965.jpg
#   inflating: train/3966.jpg
#   inflating: train/3967.jpg
#   inflating: train/3968.jpg
#   inflating: train/3969.jpg
#   inflating: train/397.jpg
#   inflating: train/3970.jpg
#   inflating: train/3971.jpg
#   inflating: train/3972.jpg
#   inflating: train/3973.jpg
#   inflating: train/3974.jpg
#   inflating: train/3975.jpg
#   inflating: train/3976.jpg
#   inflating: train/3977.jpg
#   inflating: train/3978.jpg
#   inflating: train/3979.jpg
#   inflating: train/398.jpg
#   inflating: train/3980.jpg
#   inflating: train/3981.jpg
#   inflating: train/3982.jpg
#   inflating: train/3983.jpg
#   inflating: train/3984.jpg
#   inflating: train/3985.jpg
#   inflating: train/3986.jpg
#   inflating: train/3987.jpg
#   inflating: train/3988.jpg
#   inflating: train/3989.jpg
#   inflating: train/399.jpg
#   inflating: train/3990.jpg
#   inflating: train/3991.jpg
#   inflating: train/3992.jpg
#   inflating: train/3993.jpg
#   inflating: train/3994.jpg
#   inflating: train/3995.jpg
#   inflating: train/3996.jpg
#   inflating: train/3997.jpg
#   inflating: train/3998.jpg
#   inflating: train/3999.jpg
#   inflating: train/4.jpg
#   inflating: train/40.jpg
#   inflating: train/400.jpg
#   inflating: train/4000.jpg
#   inflating: train/4001.jpg
#   inflating: train/4002.jpg
#   inflating: train/4003.jpg
#   inflating: train/4004.jpg
#   inflating: train/4005.jpg
#   inflating: train/4006.jpg
#   inflating: train/4007.jpg
#   inflating: train/4008.jpg
#   inflating: train/4009.jpg
#   inflating: train/401.jpg
#   inflating: train/4010.jpg
#   inflating: train/4011.jpg
#   inflating: train/4012.jpg
#   inflating: train/4013.jpg
#   inflating: train/4014.jpg
#   inflating: train/4015.jpg
#   inflating: train/4016.jpg
#   inflating: train/4017.jpg
#   inflating: train/4018.jpg
#   inflating: train/4019.jpg
#   inflating: train/402.jpg
#   inflating: train/4020.jpg
#   inflating: train/4021.jpg
#   inflating: train/4022.jpg
#   inflating: train/4023.jpg
#   inflating: train/4024.jpg
#   inflating: train/4025.jpg
#   inflating: train/4026.jpg
#   inflating: train/4027.jpg
#   inflating: train/4028.jpg
#   inflating: train/4029.jpg
#   inflating: train/403.jpg
#   inflating: train/4030.jpg
#   inflating: train/4031.jpg
#   inflating: train/4032.jpg
#   inflating: train/4033.jpg
#   inflating: train/4034.jpg
#   inflating: train/4035.jpg
#   inflating: train/4036.jpg
#   inflating: train/4037.jpg
#   inflating: train/4038.jpg
#   inflating: train/4039.jpg
#   inflating: train/404.jpg
#   inflating: train/4040.jpg
#   inflating: train/4041.jpg
#   inflating: train/4042.jpg
#   inflating: train/4043.jpg
#   inflating: train/4044.jpg
#   inflating: train/4045.jpg
#   inflating: train/4046.jpg
#   inflating: train/4047.jpg
#   inflating: train/4048.jpg
#   inflating: train/4049.jpg
#   inflating: train/405.jpg
#   inflating: train/4050.jpg
#   inflating: train/4051.jpg
#   inflating: train/4052.jpg
#   inflating: train/4053.jpg
#   inflating: train/4054.jpg
#   inflating: train/4055.jpg
#   inflating: train/4056.jpg
#   inflating: train/4057.jpg
#   inflating: train/4058.jpg
#   inflating: train/4059.jpg
#   inflating: train/406.jpg
#   inflating: train/4060.jpg
#   inflating: train/4061.jpg
#   inflating: train/4062.jpg
#   inflating: train/4063.jpg
#   inflating: train/4064.jpg
#   inflating: train/4065.jpg
#   inflating: train/4066.jpg
#   inflating: train/4067.jpg
#   inflating: train/4068.jpg
#   inflating: train/4069.jpg
#   inflating: train/407.jpg
#   inflating: train/4070.jpg
#   inflating: train/4071.jpg
#   inflating: train/4072.jpg
#   inflating: train/4073.jpg
#   inflating: train/4074.jpg
#   inflating: train/4075.jpg
#   inflating: train/4076.jpg
#   inflating: train/4077.jpg
#   inflating: train/4078.jpg
#   inflating: train/4079.jpg
#   inflating: train/408.jpg
#   inflating: train/4080.jpg
#   inflating: train/4081.jpg
#   inflating: train/4082.jpg
#   inflating: train/4083.jpg
#   inflating: train/4084.jpg
#   inflating: train/4085.jpg
#   inflating: train/4086.jpg
#   inflating: train/4087.jpg
#   inflating: train/4088.jpg
#   inflating: train/4089.jpg
#   inflating: train/409.jpg
#   inflating: train/4090.jpg
#   inflating: train/4091.jpg
#   inflating: train/4092.jpg
#   inflating: train/4093.jpg
#   inflating: train/4094.jpg
#   inflating: train/4095.jpg
#   inflating: train/4096.jpg
#   inflating: train/4097.jpg
#   inflating: train/4098.jpg
#   inflating: train/4099.jpg
#   inflating: train/41.jpg
#   inflating: train/410.jpg
#   inflating: train/4100.jpg
#   inflating: train/4101.jpg
#   inflating: train/4102.jpg
#   inflating: train/4103.jpg
#   inflating: train/4104.jpg
#   inflating: train/4105.jpg
#   inflating: train/4106.jpg
#   inflating: train/4107.jpg
#   inflating: train/4108.jpg
#   inflating: train/4109.jpg
#   inflating: train/411.jpg
#   inflating: train/4110.jpg
#   inflating: train/4111.jpg
#   inflating: train/4112.jpg
#   inflating: train/4113.jpg
#   inflating: train/4114.jpg
#   inflating: train/4115.jpg
#   inflating: train/4116.jpg
#   inflating: train/4117.jpg
#   inflating: train/4118.jpg
#   inflating: train/4119.jpg
#   inflating: train/412.jpg
#   inflating: train/4120.jpg
#   inflating: train/4121.jpg
#   inflating: train/4122.jpg
#   inflating: train/4123.jpg
#   inflating: train/4124.jpg
#   inflating: train/4125.jpg
#   inflating: train/4126.jpg
#   inflating: train/4127.jpg
#   inflating: train/4128.jpg
#   inflating: train/4129.jpg
#   inflating: train/413.jpg
#   inflating: train/4130.jpg
#   inflating: train/4131.jpg
#   inflating: train/4132.jpg
#   inflating: train/4133.jpg
#   inflating: train/4134.jpg
#   inflating: train/4135.jpg
#   inflating: train/4136.jpg
#   inflating: train/4137.jpg
#   inflating: train/4138.jpg
#   inflating: train/4139.jpg
#   inflating: train/414.jpg
#   inflating: train/4140.jpg
#   inflating: train/4141.jpg
#   inflating: train/4142.jpg
#   inflating: train/4143.jpg
#   inflating: train/4144.jpg
#   inflating: train/4145.jpg
#   inflating: train/4146.jpg
#   inflating: train/4147.jpg
#   inflating: train/4148.jpg
#   inflating: train/4149.jpg
#   inflating: train/415.jpg
#   inflating: train/4150.jpg
#   inflating: train/4151.jpg
#   inflating: train/4152.jpg
#   inflating: train/4153.jpg
#   inflating: train/4154.jpg
#   inflating: train/4155.jpg
#   inflating: train/4156.jpg
#   inflating: train/4157.jpg
#   inflating: train/4158.jpg
#   inflating: train/4159.jpg
#   inflating: train/416.jpg
#   inflating: train/4160.jpg
#   inflating: train/4161.jpg
#   inflating: train/4162.jpg
#   inflating: train/4163.jpg
#   inflating: train/4164.jpg
#   inflating: train/4165.jpg
#   inflating: train/4166.jpg
#   inflating: train/4167.jpg
#   inflating: train/4168.jpg
#   inflating: train/4169.jpg
#   inflating: train/417.jpg
#   inflating: train/4170.jpg
#   inflating: train/4171.jpg
#   inflating: train/4172.jpg
#   inflating: train/4173.jpg
#   inflating: train/4174.jpg
#   inflating: train/4175.jpg
#   inflating: train/4176.jpg
#   inflating: train/4177.jpg
#   inflating: train/4178.jpg
#   inflating: train/4179.jpg
#   inflating: train/418.jpg
#   inflating: train/4180.jpg
#   inflating: train/4181.jpg
#   inflating: train/4182.jpg
#   inflating: train/4183.jpg
#   inflating: train/4184.jpg
#   inflating: train/4185.jpg
#   inflating: train/4186.jpg
#   inflating: train/4187.jpg
#   inflating: train/4188.jpg
#   inflating: train/4189.jpg
#   inflating: train/419.jpg
#   inflating: train/4190.jpg
#   inflating: train/4191.jpg
#   inflating: train/4192.jpg
#   inflating: train/4193.jpg
#   inflating: train/4194.jpg
#   inflating: train/4195.jpg
#   inflating: train/4196.jpg
#   inflating: train/4197.jpg
#   inflating: train/4198.jpg
#   inflating: train/4199.jpg
#   inflating: train/42.jpg
#   inflating: train/420.jpg
#   inflating: train/4200.jpg
#   inflating: train/4201.jpg
#   inflating: train/4202.jpg
#   inflating: train/4203.jpg
#   inflating: train/4204.jpg
#   inflating: train/4205.jpg
#   inflating: train/4206.jpg
#   inflating: train/4207.jpg
#   inflating: train/4208.jpg
#   inflating: train/4209.jpg
#   inflating: train/421.jpg
#   inflating: train/4210.jpg
#   inflating: train/4211.jpg
#   inflating: train/4212.jpg
#   inflating: train/4213.jpg
#   inflating: train/4214.jpg
#   inflating: train/4215.jpg
#   inflating: train/4216.jpg
#   inflating: train/4217.jpg
#   inflating: train/4218.jpg
#   inflating: train/4219.jpg
#   inflating: train/422.jpg
#   inflating: train/4220.jpg
#   inflating: train/4221.jpg
#   inflating: train/4222.jpg
#   inflating: train/4223.jpg
#   inflating: train/4224.jpg
#   inflating: train/4225.jpg
#   inflating: train/4226.jpg
#   inflating: train/4227.jpg
#   inflating: train/4228.jpg
#   inflating: train/4229.jpg
#   inflating: train/423.jpg
#   inflating: train/4230.jpg
#   inflating: train/4231.jpg
#   inflating: train/4232.jpg
#   inflating: train/4233.jpg
#   inflating: train/4234.jpg
#   inflating: train/4235.jpg
#   inflating: train/4236.jpg
#   inflating: train/4237.jpg
#   inflating: train/4238.jpg
#   inflating: train/4239.jpg
#   inflating: train/424.jpg
#   inflating: train/4240.jpg
#   inflating: train/4241.jpg
#   inflating: train/4242.jpg
#   inflating: train/4243.jpg
#   inflating: train/4244.jpg
#   inflating: train/4245.jpg
#   inflating: train/4246.jpg
#   inflating: train/4247.jpg
#   inflating: train/4248.jpg
#   inflating: train/4249.jpg
#   inflating: train/425.jpg
#   inflating: train/4250.jpg
#   inflating: train/4251.jpg
#   inflating: train/4252.jpg
#   inflating: train/4253.jpg
#   inflating: train/4254.jpg
#   inflating: train/4255.jpg
#   inflating: train/4256.jpg
#   inflating: train/4257.jpg
#   inflating: train/4258.jpg
#   inflating: train/4259.jpg
#   inflating: train/426.jpg
#   inflating: train/4260.jpg
#   inflating: train/4261.jpg
#   inflating: train/4262.jpg
#   inflating: train/4263.jpg
#   inflating: train/4264.jpg
#   inflating: train/4265.jpg
#   inflating: train/4266.jpg
#   inflating: train/4267.jpg
#   inflating: train/4268.jpg
#   inflating: train/4269.jpg
#   inflating: train/427.jpg
#   inflating: train/4270.jpg
#   inflating: train/4271.jpg
#   inflating: train/4272.jpg
#   inflating: train/4273.jpg
#   inflating: train/4274.jpg
#   inflating: train/4275.jpg
#   inflating: train/4276.jpg
#   inflating: train/4277.jpg
#   inflating: train/4278.jpg
#   inflating: train/4279.jpg
#   inflating: train/428.jpg
#   inflating: train/4280.jpg
#   inflating: train/4281.jpg
#   inflating: train/4282.jpg
#   inflating: train/4283.jpg
#   inflating: train/4284.jpg
#   inflating: train/4285.jpg
#   inflating: train/4286.jpg
#   inflating: train/4287.jpg
#   inflating: train/4288.jpg
#   inflating: train/4289.jpg
#   inflating: train/429.jpg
#   inflating: train/4290.jpg
#   inflating: train/4291.jpg
#   inflating: train/4292.jpg
#   inflating: train/4293.jpg
#   inflating: train/4294.jpg
#   inflating: train/4295.jpg
#   inflating: train/4296.jpg
#   inflating: train/4297.jpg
#   inflating: train/4298.jpg
#   inflating: train/4299.jpg
#   inflating: train/43.jpg
#   inflating: train/430.jpg
#   inflating: train/4300.jpg
#   inflating: train/4301.jpg
#   inflating: train/4302.jpg
#   inflating: train/4303.jpg
#   inflating: train/4304.jpg
#   inflating: train/4305.jpg
#   inflating: train/4306.jpg
#   inflating: train/4307.jpg
#   inflating: train/4308.jpg
#   inflating: train/4309.jpg
#   inflating: train/431.jpg
#   inflating: train/4310.jpg
#   inflating: train/4311.jpg
#   inflating: train/4312.jpg
#   inflating: train/4313.jpg
#   inflating: train/4314.jpg
#   inflating: train/4315.jpg
#   inflating: train/4316.jpg
#   inflating: train/4317.jpg
#   inflating: train/4318.jpg
#   inflating: train/4319.jpg
#   inflating: train/432.jpg
#   inflating: train/4320.jpg
#   inflating: train/4321.jpg
#   inflating: train/4322.jpg
#   inflating: train/4323.jpg
#   inflating: train/4324.jpg
#   inflating: train/4325.jpg
#   inflating: train/4326.jpg
#   inflating: train/4327.jpg
#   inflating: train/4328.jpg
#   inflating: train/4329.jpg
#   inflating: train/433.jpg
#   inflating: train/4330.jpg
#   inflating: train/4331.jpg
#   inflating: train/4332.jpg
#   inflating: train/4333.jpg
#   inflating: train/4334.jpg
#   inflating: train/4335.jpg
#   inflating: train/4336.jpg
#   inflating: train/4337.jpg
#   inflating: train/4338.jpg
#   inflating: train/4339.jpg
#   inflating: train/434.jpg
#   inflating: train/4340.jpg
#   inflating: train/4341.jpg
#   inflating: train/4342.jpg
#   inflating: train/4343.jpg
#   inflating: train/4344.jpg
#   inflating: train/4345.jpg
#   inflating: train/4346.jpg
#   inflating: train/4347.jpg
#   inflating: train/4348.jpg
#   inflating: train/4349.jpg
#   inflating: train/435.jpg
#   inflating: train/4350.jpg
#   inflating: train/4351.jpg
#   inflating: train/4352.jpg
#   inflating: train/4353.jpg
#   inflating: train/4354.jpg
#   inflating: train/4355.jpg
#   inflating: train/4356.jpg
#   inflating: train/4357.jpg
#   inflating: train/4358.jpg
#   inflating: train/4359.jpg
#   inflating: train/436.jpg
#   inflating: train/4360.jpg
#   inflating: train/4361.jpg
#   inflating: train/4362.jpg
#   inflating: train/4363.jpg
#   inflating: train/4364.jpg
#   inflating: train/4365.jpg
#   inflating: train/4366.jpg
#   inflating: train/4367.jpg
#   inflating: train/4368.jpg
#   inflating: train/4369.jpg
#   inflating: train/437.jpg
#   inflating: train/4370.jpg
#   inflating: train/4371.jpg
#   inflating: train/4372.jpg
#   inflating: train/4373.jpg
#   inflating: train/4374.jpg
#   inflating: train/4375.jpg
#   inflating: train/4376.jpg
#   inflating: train/4377.jpg
#   inflating: train/4378.jpg
#   inflating: train/4379.jpg
#   inflating: train/438.jpg
#   inflating: train/4380.jpg
#   inflating: train/4381.jpg
#   inflating: train/4382.jpg
#   inflating: train/4383.jpg
#   inflating: train/4384.jpg
#   inflating: train/4385.jpg
#   inflating: train/4386.jpg
#   inflating: train/4387.jpg
#   inflating: train/4388.jpg
#   inflating: train/4389.jpg
#   inflating: train/439.jpg
#   inflating: train/4390.jpg
#   inflating: train/4391.jpg
#   inflating: train/4392.jpg
#   inflating: train/4393.jpg
#   inflating: train/4394.jpg
#   inflating: train/4395.jpg
#   inflating: train/4396.jpg
#   inflating: train/4397.jpg
#   inflating: train/4398.jpg
#   inflating: train/4399.jpg
#   inflating: train/44.jpg
#   inflating: train/440.jpg
#   inflating: train/4400.jpg
#   inflating: train/4401.jpg
#   inflating: train/4402.jpg
#   inflating: train/4403.jpg
#   inflating: train/4404.jpg
#   inflating: train/4405.jpg
#   inflating: train/4406.jpg
#   inflating: train/4407.jpg
#   inflating: train/4408.jpg
#   inflating: train/4409.jpg
#   inflating: train/441.jpg
#   inflating: train/4410.jpg
#   inflating: train/4411.jpg
#   inflating: train/4412.jpg
#   inflating: train/4413.jpg
#   inflating: train/4414.jpg
#   inflating: train/4415.jpg
#   inflating: train/4416.jpg
#   inflating: train/4417.jpg
#   inflating: train/4418.jpg
#   inflating: train/4419.jpg
#   inflating: train/442.jpg
#   inflating: train/4420.jpg
#   inflating: train/4421.jpg
#   inflating: train/4422.jpg
#   inflating: train/4423.jpg
#   inflating: train/4424.jpg
#   inflating: train/4425.jpg
#   inflating: train/4426.jpg
#   inflating: train/4427.jpg
#   inflating: train/4428.jpg
#   inflating: train/4429.jpg
#   inflating: train/443.jpg
#   inflating: train/4430.jpg
#   inflating: train/4431.jpg
#   inflating: train/4432.jpg
#   inflating: train/4433.jpg
#   inflating: train/4434.jpg
#   inflating: train/4435.jpg
#   inflating: train/4436.jpg
#   inflating: train/4437.jpg
#   inflating: train/4438.jpg
#   inflating: train/4439.jpg
#   inflating: train/444.jpg
#   inflating: train/4440.jpg
#   inflating: train/4441.jpg
#   inflating: train/4442.jpg
#   inflating: train/4443.jpg
#   inflating: train/4444.jpg
#   inflating: train/4445.jpg
#   inflating: train/4446.jpg
#   inflating: train/4447.jpg
#   inflating: train/4448.jpg
#   inflating: train/4449.jpg
#   inflating: train/445.jpg
#   inflating: train/4450.jpg
#   inflating: train/4451.jpg
#   inflating: train/4452.jpg
#   inflating: train/4453.jpg
#   inflating: train/4454.jpg
#   inflating: train/4455.jpg
#   inflating: train/4456.jpg
#   inflating: train/4457.jpg
#   inflating: train/4458.jpg
#   inflating: train/4459.jpg
#   inflating: train/446.jpg
#   inflating: train/4460.jpg
#   inflating: train/4461.jpg
#   inflating: train/4462.jpg
#   inflating: train/4463.jpg
#   inflating: train/4464.jpg
#   inflating: train/4465.jpg
#   inflating: train/4466.jpg
#   inflating: train/4467.jpg
#   inflating: train/4468.jpg
#   inflating: train/4469.jpg
#   inflating: train/447.jpg
#   inflating: train/4470.jpg
#   inflating: train/4471.jpg
#   inflating: train/4472.jpg
#   inflating: train/4473.jpg
#   inflating: train/4474.jpg
#   inflating: train/4475.jpg
#   inflating: train/4476.jpg
#   inflating: train/4477.jpg
#   inflating: train/4478.jpg
#   inflating: train/4479.jpg
#   inflating: train/448.jpg
#   inflating: train/4480.jpg
#   inflating: train/4481.jpg
#   inflating: train/4482.jpg
#   inflating: train/4483.jpg
#   inflating: train/4484.jpg
#   inflating: train/4485.jpg
#   inflating: train/4486.jpg
#   inflating: train/4487.jpg
#   inflating: train/4488.jpg
#   inflating: train/4489.jpg
#   inflating: train/449.jpg
#   inflating: train/4490.jpg
#   inflating: train/4491.jpg
#   inflating: train/4492.jpg
#   inflating: train/4493.jpg
#   inflating: train/4494.jpg
#   inflating: train/4495.jpg
#   inflating: train/4496.jpg
#   inflating: train/4497.jpg
#   inflating: train/4498.jpg
#   inflating: train/4499.jpg
#   inflating: train/45.jpg
#   inflating: train/450.jpg
#   inflating: train/4500.jpg
#   inflating: train/4501.jpg
#   inflating: train/4502.jpg
#   inflating: train/4503.jpg
#   inflating: train/4504.jpg
#   inflating: train/4505.jpg
#   inflating: train/4506.jpg
#   inflating: train/4507.jpg
#   inflating: train/4508.jpg
#   inflating: train/4509.jpg
#   inflating: train/451.jpg
#   inflating: train/4510.jpg
#   inflating: train/4511.jpg
#   inflating: train/4512.jpg
#   inflating: train/4513.jpg
#   inflating: train/4514.jpg
#   inflating: train/4515.jpg
#   inflating: train/4516.jpg
#   inflating: train/4517.jpg
#   inflating: train/4518.jpg
#   inflating: train/4519.jpg
#   inflating: train/452.jpg
#   inflating: train/4520.jpg
#   inflating: train/4521.jpg
#   inflating: train/4522.jpg
#   inflating: train/4523.jpg
#   inflating: train/4524.jpg
#   inflating: train/4525.jpg
#   inflating: train/4526.jpg
#   inflating: train/4527.jpg
#   inflating: train/4528.jpg
#   inflating: train/4529.jpg
#   inflating: train/453.jpg
#   inflating: train/4530.jpg
#   inflating: train/4531.jpg
#   inflating: train/4532.jpg
#   inflating: train/4533.jpg
#   inflating: train/4534.jpg
#   inflating: train/4535.jpg
#   inflating: train/4536.jpg
#   inflating: train/4537.jpg
#   inflating: train/4538.jpg
#   inflating: train/4539.jpg
#   inflating: train/454.jpg
#   inflating: train/4540.jpg
#   inflating: train/4541.jpg
#   inflating: train/4542.jpg
#   inflating: train/4543.jpg
#   inflating: train/4544.jpg
#   inflating: train/4545.jpg
#   inflating: train/4546.jpg
#   inflating: train/4547.jpg
#   inflating: train/4548.jpg
#   inflating: train/4549.jpg
#   inflating: train/455.jpg
#   inflating: train/4550.jpg
#   inflating: train/4551.jpg
#   inflating: train/4552.jpg
#   inflating: train/4553.jpg
#   inflating: train/4554.jpg
#   inflating: train/4555.jpg
#   inflating: train/4556.jpg
#   inflating: train/4557.jpg
#   inflating: train/4558.jpg
#   inflating: train/4559.jpg
#   inflating: train/456.jpg
#   inflating: train/4560.jpg
#   inflating: train/4561.jpg
#   inflating: train/4562.jpg
#   inflating: train/4563.jpg
#   inflating: train/4564.jpg
#   inflating: train/4565.jpg
#   inflating: train/4566.jpg
#   inflating: train/4567.jpg
#   inflating: train/4568.jpg
#   inflating: train/4569.jpg
#   inflating: train/457.jpg
#   inflating: train/4570.jpg
#   inflating: train/4571.jpg
#   inflating: train/4572.jpg
#   inflating: train/4573.jpg
#   inflating: train/4574.jpg
#   inflating: train/4575.jpg
#   inflating: train/4576.jpg
#   inflating: train/4577.jpg
#   inflating: train/4578.jpg
#   inflating: train/4579.jpg
#   inflating: train/458.jpg
#   inflating: train/4580.jpg
#   inflating: train/4581.jpg
#   inflating: train/4582.jpg
#   inflating: train/4583.jpg
#   inflating: train/4584.jpg
#   inflating: train/4585.jpg
#   inflating: train/4586.jpg
#   inflating: train/4587.jpg
#   inflating: train/4588.jpg
#   inflating: train/4589.jpg
#   inflating: train/459.jpg
#   inflating: train/4590.jpg
#   inflating: train/4591.jpg
#   inflating: train/4592.jpg
#   inflating: train/4593.jpg
#   inflating: train/4594.jpg
#   inflating: train/4595.jpg
#   inflating: train/4596.jpg
#   inflating: train/4597.jpg
#   inflating: train/4598.jpg
#   inflating: train/4599.jpg
#   inflating: train/46.jpg
#   inflating: train/460.jpg
#   inflating: train/4600.jpg
#   inflating: train/4601.jpg
#   inflating: train/4602.jpg
#   inflating: train/4603.jpg
#   inflating: train/4604.jpg
#   inflating: train/4605.jpg
#   inflating: train/4606.jpg
#   inflating: train/4607.jpg
#   inflating: train/4608.jpg
#   inflating: train/4609.jpg
#   inflating: train/461.jpg
#   inflating: train/4610.jpg
#   inflating: train/4611.jpg
#   inflating: train/4612.jpg
#   inflating: train/4613.jpg
#   inflating: train/4614.jpg
#   inflating: train/4615.jpg
#   inflating: train/4616.jpg
#   inflating: train/4617.jpg
#   inflating: train/4618.jpg
#   inflating: train/4619.jpg
#   inflating: train/462.jpg
#   inflating: train/4620.jpg
#   inflating: train/4621.jpg
#   inflating: train/4622.jpg
#   inflating: train/4623.jpg
#   inflating: train/4624.jpg
#   inflating: train/4625.jpg
#   inflating: train/4626.jpg
#   inflating: train/4627.jpg
#   inflating: train/4628.jpg
#   inflating: train/4629.jpg
#   inflating: train/463.jpg
#   inflating: train/4630.jpg
#   inflating: train/4631.jpg
#   inflating: train/4632.jpg
#   inflating: train/4633.jpg
#   inflating: train/4634.jpg
#   inflating: train/4635.jpg
#   inflating: train/4636.jpg
#   inflating: train/4637.jpg
#   inflating: train/4638.jpg
#   inflating: train/4639.jpg
#   inflating: train/464.jpg
#   inflating: train/4640.jpg
#   inflating: train/4641.jpg
#   inflating: train/4642.jpg
#   inflating: train/4643.jpg
#   inflating: train/4644.jpg
#   inflating: train/4645.jpg
#   inflating: train/4646.jpg
#   inflating: train/4647.jpg
#   inflating: train/4648.jpg
#   inflating: train/4649.jpg
#   inflating: train/465.jpg
#   inflating: train/4650.jpg
#   inflating: train/4651.jpg
#   inflating: train/4652.jpg
#   inflating: train/4653.jpg
#   inflating: train/4654.jpg
#   inflating: train/4655.jpg
#   inflating: train/4656.jpg
#   inflating: train/4657.jpg
#   inflating: train/4658.jpg
#   inflating: train/4659.jpg
#   inflating: train/466.jpg
#   inflating: train/4660.jpg
#   inflating: train/4661.jpg
#   inflating: train/4662.jpg
#   inflating: train/4663.jpg
#   inflating: train/4664.jpg
#   inflating: train/4665.jpg
#   inflating: train/4666.jpg
#   inflating: train/4667.jpg
#   inflating: train/4668.jpg
#   inflating: train/4669.jpg
#   inflating: train/467.jpg
#   inflating: train/4670.jpg
#   inflating: train/4671.jpg
#   inflating: train/4672.jpg
#   inflating: train/4673.jpg
#   inflating: train/4674.jpg
#   inflating: train/4675.jpg
#   inflating: train/4676.jpg
#   inflating: train/4677.jpg
#   inflating: train/4678.jpg
#   inflating: train/4679.jpg
#   inflating: train/468.jpg
#   inflating: train/4680.jpg
#   inflating: train/4681.jpg
#   inflating: train/4682.jpg
#   inflating: train/4683.jpg
#   inflating: train/4684.jpg
#   inflating: train/4685.jpg
#   inflating: train/4686.jpg
#   inflating: train/4687.jpg
#   inflating: train/4688.jpg
#   inflating: train/4689.jpg
#   inflating: train/469.jpg
#   inflating: train/4690.jpg
#   inflating: train/4691.jpg
#   inflating: train/4692.jpg
#   inflating: train/4693.jpg
#   inflating: train/4694.jpg
#   inflating: train/4695.jpg
#   inflating: train/4696.jpg
#   inflating: train/4697.jpg
#   inflating: train/4698.jpg
#   inflating: train/4699.jpg
#   inflating: train/47.jpg
#   inflating: train/470.jpg
#   inflating: train/4700.jpg
#   inflating: train/4701.jpg
#   inflating: train/4702.jpg
#   inflating: train/4703.jpg
#   inflating: train/4704.jpg
#   inflating: train/4705.jpg
#   inflating: train/4706.jpg
#   inflating: train/4707.jpg
#   inflating: train/4708.jpg
#   inflating: train/4709.jpg
#   inflating: train/471.jpg
#   inflating: train/4710.jpg
#   inflating: train/4711.jpg
#   inflating: train/4712.jpg
#   inflating: train/4713.jpg
#   inflating: train/4714.jpg
#   inflating: train/4715.jpg
#   inflating: train/4716.jpg
#   inflating: train/4717.jpg
#   inflating: train/4718.jpg
#   inflating: train/4719.jpg
#   inflating: train/472.jpg
#   inflating: train/4720.jpg
#   inflating: train/4721.jpg
#   inflating: train/4722.jpg
#   inflating: train/4723.jpg
#   inflating: train/4724.jpg
#   inflating: train/4725.jpg
#   inflating: train/4726.jpg
#   inflating: train/4727.jpg
#   inflating: train/4728.jpg
#   inflating: train/4729.jpg
#   inflating: train/473.jpg
#   inflating: train/4730.jpg
#   inflating: train/4731.jpg
#   inflating: train/4732.jpg
#   inflating: train/4733.jpg
#   inflating: train/4734.jpg
#   inflating: train/4735.jpg
#   inflating: train/4736.jpg
#   inflating: train/4737.jpg
#   inflating: train/4738.jpg
#   inflating: train/4739.jpg
#   inflating: train/474.jpg
#   inflating: train/4740.jpg
#   inflating: train/4741.jpg
#   inflating: train/4742.jpg
#   inflating: train/4743.jpg
#   inflating: train/4744.jpg
#   inflating: train/4745.jpg
#   inflating: train/4746.jpg
#   inflating: train/4747.jpg
#   inflating: train/4748.jpg
#   inflating: train/4749.jpg
#   inflating: train/475.jpg
#   inflating: train/4750.jpg
#   inflating: train/4751.jpg
#   inflating: train/4752.jpg
#   inflating: train/4753.jpg
#   inflating: train/4754.jpg
#   inflating: train/4755.jpg
#   inflating: train/4756.jpg
#   inflating: train/4757.jpg
#   inflating: train/4758.jpg
#   inflating: train/4759.jpg
#   inflating: train/476.jpg
#   inflating: train/4760.jpg
#   inflating: train/4761.jpg
#   inflating: train/4762.jpg
#   inflating: train/4763.jpg
#   inflating: train/4764.jpg
#   inflating: train/4765.jpg
#   inflating: train/4766.jpg
#   inflating: train/4767.jpg
#   inflating: train/4768.jpg
#   inflating: train/4769.jpg
#   inflating: train/477.jpg
#   inflating: train/4770.jpg
#   inflating: train/4771.jpg
#   inflating: train/4772.jpg
#   inflating: train/4773.jpg
#   inflating: train/4774.jpg
#   inflating: train/4775.jpg
#   inflating: train/4776.jpg
#   inflating: train/4777.jpg
#   inflating: train/4778.jpg
#   inflating: train/4779.jpg
#   inflating: train/478.jpg
#   inflating: train/4780.jpg
#   inflating: train/4781.jpg
#   inflating: train/4782.jpg
#   inflating: train/4783.jpg
#   inflating: train/4784.jpg
#   inflating: train/4785.jpg
#   inflating: train/4786.jpg
#   inflating: train/4787.jpg
#   inflating: train/4788.jpg
#   inflating: train/4789.jpg
#   inflating: train/479.jpg
#   inflating: train/4790.jpg
#   inflating: train/4791.jpg
#   inflating: train/4792.jpg
#   inflating: train/4793.jpg
#   inflating: train/4794.jpg
#   inflating: train/4795.jpg
#   inflating: train/4796.jpg
#   inflating: train/4797.jpg
#   inflating: train/4798.jpg
#   inflating: train/4799.jpg
#   inflating: train/48.jpg
#   inflating: train/480.jpg
#   inflating: train/4800.jpg
#   inflating: train/4801.jpg
#   inflating: train/4802.jpg
#   inflating: train/4803.jpg
#   inflating: train/4804.jpg
#   inflating: train/4805.jpg
#   inflating: train/4806.jpg
#   inflating: train/4807.jpg
#   inflating: train/4808.jpg
#   inflating: train/4809.jpg
#   inflating: train/481.jpg
#   inflating: train/4810.jpg
#   inflating: train/4811.jpg
#   inflating: train/4812.jpg
#   inflating: train/4813.jpg
#   inflating: train/4814.jpg
#   inflating: train/4815.jpg
#   inflating: train/4816.jpg
#   inflating: train/4817.jpg
#   inflating: train/4818.jpg
#   inflating: train/4819.jpg
#   inflating: train/482.jpg
#   inflating: train/4820.jpg
#   inflating: train/4821.jpg
#   inflating: train/4822.jpg
#   inflating: train/4823.jpg
#   inflating: train/4824.jpg
#   inflating: train/4825.jpg
#   inflating: train/4826.jpg
#   inflating: train/4827.jpg
#   inflating: train/4828.jpg
#   inflating: train/4829.jpg
#   inflating: train/483.jpg
#   inflating: train/4830.jpg
#   inflating: train/4831.jpg
#   inflating: train/4832.jpg
#   inflating: train/4833.jpg
#   inflating: train/4834.jpg
#   inflating: train/4835.jpg
#   inflating: train/4836.jpg
#   inflating: train/4837.jpg
#   inflating: train/4838.jpg
#   inflating: train/4839.jpg
#   inflating: train/484.jpg
#   inflating: train/4840.jpg
#   inflating: train/4841.jpg
#   inflating: train/4842.jpg
#   inflating: train/4843.jpg
#   inflating: train/4844.jpg
#   inflating: train/4845.jpg
#   inflating: train/4846.jpg
#   inflating: train/4847.jpg
#   inflating: train/4848.jpg
#   inflating: train/4849.jpg
#   inflating: train/485.jpg
#   inflating: train/4850.jpg
#   inflating: train/4851.jpg
#   inflating: train/4852.jpg
#   inflating: train/4853.jpg
#   inflating: train/4854.jpg
#   inflating: train/4855.jpg
#   inflating: train/4856.jpg
#   inflating: train/4857.jpg
#   inflating: train/4858.jpg
#   inflating: train/4859.jpg
#   inflating: train/486.jpg
#   inflating: train/4860.jpg
#   inflating: train/4861.jpg
#   inflating: train/4862.jpg
#   inflating: train/4863.jpg
#   inflating: train/4864.jpg
#   inflating: train/4865.jpg
#   inflating: train/4866.jpg
#   inflating: train/4867.jpg
#   inflating: train/4868.jpg
#   inflating: train/4869.jpg
#   inflating: train/487.jpg
#   inflating: train/4870.jpg
#   inflating: train/4871.jpg
#   inflating: train/4872.jpg
#   inflating: train/4873.jpg
#   inflating: train/4874.jpg
#   inflating: train/4875.jpg
#   inflating: train/4876.jpg
#   inflating: train/4877.jpg
#   inflating: train/4878.jpg
#   inflating: train/4879.jpg
#   inflating: train/488.jpg
#   inflating: train/4880.jpg
#   inflating: train/4881.jpg
#   inflating: train/4882.jpg
#   inflating: train/4883.jpg
#   inflating: train/4884.jpg
#   inflating: train/4885.jpg
#   inflating: train/4886.jpg
#   inflating: train/4887.jpg
#   inflating: train/4888.jpg
#   inflating: train/4889.jpg
#   inflating: train/489.jpg
#   inflating: train/4890.jpg
#   inflating: train/4891.jpg
#   inflating: train/4892.jpg
#   inflating: train/4893.jpg
#   inflating: train/4894.jpg
#   inflating: train/4895.jpg
#   inflating: train/4896.jpg
#   inflating: train/4897.jpg
#   inflating: train/4898.jpg
#   inflating: train/4899.jpg
#   inflating: train/49.jpg
#   inflating: train/490.jpg
#   inflating: train/4900.jpg
#   inflating: train/4901.jpg
#   inflating: train/4902.jpg
#   inflating: train/4903.jpg
#   inflating: train/4904.jpg
#   inflating: train/4905.jpg
#   inflating: train/4906.jpg
#   inflating: train/4907.jpg
#   inflating: train/4908.jpg
#   inflating: train/4909.jpg
#   inflating: train/491.jpg
#   inflating: train/4910.jpg
#   inflating: train/4911.jpg
#   inflating: train/4912.jpg
#   inflating: train/4913.jpg
#   inflating: train/4914.jpg
#   inflating: train/4915.jpg
#   inflating: train/4916.jpg
#   inflating: train/4917.jpg
#   inflating: train/4918.jpg
#   inflating: train/4919.jpg
#   inflating: train/492.jpg
#   inflating: train/4920.jpg
#   inflating: train/4921.jpg
#   inflating: train/4922.jpg
#   inflating: train/4923.jpg
#   inflating: train/4924.jpg
#   inflating: train/4925.jpg
#   inflating: train/4926.jpg
#   inflating: train/4927.jpg
#   inflating: train/4928.jpg
#   inflating: train/4929.jpg
#   inflating: train/493.jpg
#   inflating: train/4930.jpg
#   inflating: train/4931.jpg
#   inflating: train/4932.jpg
#   inflating: train/4933.jpg
#   inflating: train/4934.jpg
#   inflating: train/4935.jpg
#   inflating: train/4936.jpg
#   inflating: train/4937.jpg
#   inflating: train/4938.jpg
#   inflating: train/4939.jpg
#   inflating: train/494.jpg
#   inflating: train/4940.jpg
#   inflating: train/4941.jpg
#   inflating: train/4942.jpg
#   inflating: train/4943.jpg
#   inflating: train/4944.jpg
#   inflating: train/4945.jpg
#   inflating: train/4946.jpg
#   inflating: train/4947.jpg
#   inflating: train/4948.jpg
#   inflating: train/4949.jpg
#   inflating: train/495.jpg
#   inflating: train/4950.jpg
#   inflating: train/4951.jpg
#   inflating: train/4952.jpg
#   inflating: train/4953.jpg
#   inflating: train/4954.jpg
#   inflating: train/4955.jpg
#   inflating: train/4956.jpg
#   inflating: train/4957.jpg
#   inflating: train/4958.jpg
#   inflating: train/4959.jpg
#   inflating: train/496.jpg
#   inflating: train/4960.jpg
#   inflating: train/4961.jpg
#   inflating: train/4962.jpg
#   inflating: train/4963.jpg
#   inflating: train/4964.jpg
#   inflating: train/4965.jpg
#   inflating: train/4966.jpg
#   inflating: train/4967.jpg
#   inflating: train/4968.jpg
#   inflating: train/4969.jpg
#   inflating: train/497.jpg
#   inflating: train/4970.jpg
#   inflating: train/4971.jpg
#   inflating: train/4972.jpg
#   inflating: train/4973.jpg
#   inflating: train/4974.jpg
#   inflating: train/4975.jpg
#   inflating: train/4976.jpg
#   inflating: train/4977.jpg
#   inflating: train/4978.jpg
#   inflating: train/4979.jpg
#   inflating: train/498.jpg
#   inflating: train/4980.jpg
#   inflating: train/4981.jpg
#   inflating: train/4982.jpg
#   inflating: train/4983.jpg
#   inflating: train/4984.jpg
#   inflating: train/4985.jpg
#   inflating: train/4986.jpg
#   inflating: train/4987.jpg
#   inflating: train/4988.jpg
#   inflating: train/4989.jpg
#   inflating: train/499.jpg
#   inflating: train/4990.jpg
#   inflating: train/4991.jpg
#   inflating: train/4992.jpg
#   inflating: train/4993.jpg
#   inflating: train/4994.jpg
#   inflating: train/4995.jpg
#   inflating: train/4996.jpg
#   inflating: train/4997.jpg
#   inflating: train/4998.jpg
#   inflating: train/4999.jpg
#   inflating: train/5.jpg
#   inflating: train/50.jpg
#   inflating: train/500.jpg
#   inflating: train/5000.jpg
#   inflating: train/5001.jpg
#   inflating: train/5002.jpg
#   inflating: train/5003.jpg
#   inflating: train/5004.jpg
#   inflating: train/5005.jpg
#   inflating: train/5006.jpg
#   inflating: train/5007.jpg
#   inflating: train/5008.jpg
#   inflating: train/5009.jpg
#   inflating: train/501.jpg
#   inflating: train/5010.jpg
#   inflating: train/5011.jpg
#   inflating: train/5012.jpg
#   inflating: train/5013.jpg
# ...
#   inflating: train/8000.jpg
#   inflating: train/8001.jpg
#   inflating: train/8002.jpg
#   inflating: train/8003.jpg
#   inflating: train/8004.jpg
#   inflating: train/8005.jpg
#   inflating: train/8006.jpg
#   inflating: train/8007.jpg
#   inflating: train/8008.jpg
#   inflating: train/8009.jpg
#   inflating: train/801.jpg
#   inflating: train/8010.jpg
#   inflating: train/8011.jpg
#   inflating: train/8012.jpg
#   inflating: train/8013.jpg
#   inflating: train/8014.jpg
#   inflating: train/8015.jpg
#   inflating: train/8016.jpg
#   inflating: train/8017.jpg
#   inflating: train/8018.jpg
#   inflating: train/8019.jpg
#   inflating: train/802.jpg
#   inflating: train/8020.jpg
#   inflating: train/8021.jpg
#   inflating: train/8022.jpg
#   inflating: train/8023.jpg
#   inflating: train/8024.jpg
#   inflating: train/8025.jpg
#   inflating: train/8026.jpg
#   inflating: train/8027.jpg
#   inflating: train/8028.jpg
#   inflating: train/8029.jpg
#   inflating: train/803.jpg
#   inflating: train/8030.jpg
#   inflating: train/8031.jpg
#   inflating: train/8032.jpg
#   inflating: train/8033.jpg
#   inflating: train/8034.jpg
#   inflating: train/8035.jpg
#   inflating: train/8036.jpg
#   inflating: train/8037.jpg
#   inflating: train/8038.jpg
#   inflating: train/8039.jpg
#   inflating: train/804.jpg
#   inflating: train/8040.jpg
#   inflating: train/8041.jpg
#   inflating: train/8042.jpg
#   inflating: train/8043.jpg
#   inflating: train/8044.jpg
#   inflating: train/8045.jpg
#   inflating: train/8046.jpg
#   inflating: train/8047.jpg
#   inflating: train/8048.jpg
#   inflating: train/8049.jpg
#   inflating: train/805.jpg
#   inflating: train/8050.jpg
#   inflating: train/8051.jpg
#   inflating: train/8052.jpg
#   inflating: train/8053.jpg
#   inflating: train/8054.jpg
#   inflating: train/8055.jpg
#   inflating: train/8056.jpg
#   inflating: train/8057.jpg
#   inflating: train/8058.jpg
#   inflating: train/8059.jpg
#   inflating: train/806.jpg
#   inflating: train/8060.jpg
#   inflating: train/8061.jpg
#   inflating: train/8062.jpg
#   inflating: train/8063.jpg
#   inflating: train/8064.jpg
#   inflating: train/8065.jpg
#   inflating: train/8066.jpg
#   inflating: train/8067.jpg
#   inflating: train/8068.jpg
#   inflating: train/8069.jpg
#   inflating: train/807.jpg
#   inflating: train/8070.jpg
#   inflating: train/8071.jpg
#   inflating: train/8072.jpg
#   inflating: train/8073.jpg
#   inflating: train/8074.jpg
#   inflating: train/8075.jpg
#   inflating: train/8076.jpg
#   inflating: train/8077.jpg
#   inflating: train/8078.jpg
#   inflating: train/8079.jpg
#   inflating: train/808.jpg
#   inflating: train/8080.jpg
#   inflating: train/8081.jpg
#   inflating: train/8082.jpg
#   inflating: train/8083.jpg
#   inflating: train/8084.jpg
#   inflating: train/8085.jpg
#   inflating: train/8086.jpg
#   inflating: train/8087.jpg
#   inflating: train/8088.jpg
#   inflating: train/8089.jpg
#   inflating: train/809.jpg
#   inflating: train/8090.jpg
#   inflating: train/8091.jpg
#   inflating: train/8092.jpg
#   inflating: train/8093.jpg
#   inflating: train/8094.jpg
#   inflating: train/8095.jpg
#   inflating: train/8096.jpg
#   inflating: train/8097.jpg
#   inflating: train/8098.jpg
#   inflating: train/8099.jpg
#   inflating: train/81.jpg
#   inflating: train/810.jpg
#   inflating: train/8100.jpg
#   inflating: train/8101.jpg
#   inflating: train/8102.jpg
#   inflating: train/8103.jpg
#   inflating: train/8104.jpg
#   inflating: train/8105.jpg
#   inflating: train/8106.jpg
#   inflating: train/8107.jpg
#   inflating: train/8108.jpg
#   inflating: train/8109.jpg
#   inflating: train/811.jpg
#   inflating: train/8110.jpg
#   inflating: train/8111.jpg
#   inflating: train/8112.jpg
#   inflating: train/8113.jpg
#   inflating: train/8114.jpg
#   inflating: train/8115.jpg
#   inflating: train/8116.jpg
#   inflating: train/8117.jpg
#   inflating: train/8118.jpg
#   inflating: train/8119.jpg
#   inflating: train/812.jpg
#   inflating: train/8120.jpg
#   inflating: train/8121.jpg
#   inflating: train/8122.jpg
#   inflating: train/8123.jpg
#   inflating: train/8124.jpg
#   inflating: train/8125.jpg
#   inflating: train/8126.jpg
#   inflating: train/8127.jpg
#   inflating: train/8128.jpg
#   inflating: train/8129.jpg
#   inflating: train/813.jpg
#   inflating: train/8130.jpg
#   inflating: train/8131.jpg
#   inflating: train/8132.jpg
#   inflating: train/8133.jpg
#   inflating: train/8134.jpg
#   inflating: train/8135.jpg
#   inflating: train/8136.jpg
#   inflating: train/8137.jpg
#   inflating: train/8138.jpg
#   inflating: train/8139.jpg
#   inflating: train/814.jpg
#   inflating: train/8140.jpg
#   inflating: train/8141.jpg
#   inflating: train/8142.jpg
#   inflating: train/8143.jpg
#   inflating: train/8144.jpg
#   inflating: train/8145.jpg
#   inflating: train/8146.jpg
#   inflating: train/8147.jpg
#   inflating: train/8148.jpg
#   inflating: train/8149.jpg
#   inflating: train/815.jpg
#   inflating: train/8150.jpg
#   inflating: train/8151.jpg
#   inflating: train/8152.jpg
#   inflating: train/8153.jpg
#   inflating: train/8154.jpg
#   inflating: train/8155.jpg
#   inflating: train/8156.jpg
#   inflating: train/8157.jpg
#   inflating: train/8158.jpg
#   inflating: train/8159.jpg
#   inflating: train/816.jpg
#   inflating: train/8160.jpg
#   inflating: train/8161.jpg
#   inflating: train/8162.jpg
#   inflating: train/8163.jpg
#   inflating: train/8164.jpg
#   inflating: train/8165.jpg
#   inflating: train/8166.jpg
#   inflating: train/8167.jpg
#   inflating: train/8168.jpg
#   inflating: train/8169.jpg
#   inflating: train/817.jpg
#   inflating: train/8170.jpg
#   inflating: train/8171.jpg
#   inflating: train/8172.jpg
#   inflating: train/8173.jpg
#   inflating: train/8174.jpg
#   inflating: train/8175.jpg
#   inflating: train/8176.jpg
#   inflating: train/8177.jpg
#   inflating: train/8178.jpg
#   inflating: train/8179.jpg
#   inflating: train/818.jpg
#   inflating: train/8180.jpg
#   inflating: train/8181.jpg
#   inflating: train/8182.jpg
#   inflating: train/8183.jpg
#   inflating: train/8184.jpg
#   inflating: train/8185.jpg
#   inflating: train/8186.jpg
#   inflating: train/8187.jpg
#   inflating: train/8188.jpg
#   inflating: train/8189.jpg
#   inflating: train/819.jpg
#   inflating: train/8190.jpg
#   inflating: train/8191.jpg
#   inflating: train/8192.jpg
#   inflating: train/8193.jpg
#   inflating: train/8194.jpg
#   inflating: train/8195.jpg
#   inflating: train/8196.jpg
#   inflating: train/8197.jpg
#   inflating: train/8198.jpg
#   inflating: train/8199.jpg
#   inflating: train/82.jpg
#   inflating: train/820.jpg
#   inflating: train/8200.jpg
#   inflating: train/8201.jpg
#   inflating: train/821.jpg
#   inflating: train/822.jpg
#   inflating: train/823.jpg
#   inflating: train/824.jpg
#   inflating: train/825.jpg
#   inflating: train/826.jpg
#   inflating: train/827.jpg
#   inflating: train/828.jpg
#   inflating: train/829.jpg
#   inflating: train/83.jpg
#   inflating: train/830.jpg
#   inflating: train/831.jpg
#   inflating: train/832.jpg
#   inflating: train/833.jpg
#   inflating: train/834.jpg
#   inflating: train/835.jpg
#   inflating: train/836.jpg
#   inflating: train/837.jpg
#   inflating: train/838.jpg
#   inflating: train/839.jpg
#   inflating: train/84.jpg
#   inflating: train/840.jpg
#   inflating: train/841.jpg
#   inflating: train/842.jpg
#   inflating: train/843.jpg
#   inflating: train/844.jpg
#   inflating: train/845.jpg
#   inflating: train/846.jpg
#   inflating: train/847.jpg
#   inflating: train/848.jpg
#   inflating: train/849.jpg
#   inflating: train/85.jpg
#   inflating: train/850.jpg
#   inflating: train/851.jpg
#   inflating: train/852.jpg
#   inflating: train/853.jpg
#   inflating: train/854.jpg
#   inflating: train/855.jpg
#   inflating: train/856.jpg
#   inflating: train/857.jpg
#   inflating: train/858.jpg
#   inflating: train/859.jpg
#   inflating: train/86.jpg
#   inflating: train/860.jpg
#   inflating: train/861.jpg
#   inflating: train/862.jpg
#   inflating: train/863.jpg
#   inflating: train/864.jpg
#   inflating: train/865.jpg
#   inflating: train/866.jpg
#   inflating: train/867.jpg
#   inflating: train/868.jpg
#   inflating: train/869.jpg
#   inflating: train/87.jpg
#   inflating: train/870.jpg
#   inflating: train/871.jpg
#   inflating: train/872.jpg
#   inflating: train/873.jpg
#   inflating: train/874.jpg
#   inflating: train/875.jpg
#   inflating: train/876.jpg
#   inflating: train/877.jpg
#   inflating: train/878.jpg
#   inflating: train/879.jpg
#   inflating: train/88.jpg
#   inflating: train/880.jpg
#   inflating: train/881.jpg
#   inflating: train/882.jpg
#   inflating: train/883.jpg
#   inflating: train/884.jpg
#   inflating: train/885.jpg
#   inflating: train/886.jpg
#   inflating: train/887.jpg
#   inflating: train/888.jpg
#   inflating: train/889.jpg
#   inflating: train/89.jpg
#   inflating: train/890.jpg
#   inflating: train/891.jpg
#   inflating: train/892.jpg
#   inflating: train/893.jpg
#   inflating: train/894.jpg
#   inflating: train/895.jpg
#   inflating: train/896.jpg
#   inflating: train/897.jpg
#   inflating: train/898.jpg
#   inflating: train/899.jpg
#   inflating: train/9.jpg
#   inflating: train/90.jpg
#   inflating: train/900.jpg
#   inflating: train/901.jpg
#   inflating: train/902.jpg
#   inflating: train/903.jpg
#   inflating: train/904.jpg
#   inflating: train/905.jpg
#   inflating: train/906.jpg
#   inflating: train/907.jpg
#   inflating: train/908.jpg
#   inflating: train/909.jpg
#   inflating: train/91.jpg
#   inflating: train/910.jpg
#   inflating: train/911.jpg
#   inflating: train/912.jpg
#   inflating: train/913.jpg
#   inflating: train/914.jpg
#   inflating: train/915.jpg
#   inflating: train/916.jpg
#   inflating: train/917.jpg
#   inflating: train/918.jpg
#   inflating: train/919.jpg
#   inflating: train/92.jpg
#   inflating: train/920.jpg
#   inflating: train/921.jpg
#   inflating: train/922.jpg
#   inflating: train/923.jpg
#   inflating: train/924.jpg
#   inflating: train/925.jpg
#   inflating: train/926.jpg
#   inflating: train/927.jpg
#   inflating: train/928.jpg
#   inflating: train/929.jpg
#   inflating: train/93.jpg
#   inflating: train/930.jpg
#   inflating: train/931.jpg
#   inflating: train/932.jpg
#   inflating: train/933.jpg
#   inflating: train/934.jpg
#   inflating: train/935.jpg
#   inflating: train/936.jpg
#   inflating: train/937.jpg
#   inflating: train/938.jpg
#   inflating: train/939.jpg
#   inflating: train/94.jpg
#   inflating: train/940.jpg
#   inflating: train/941.jpg
#   inflating: train/942.jpg
#   inflating: train/943.jpg
#   inflating: train/944.jpg
#   inflating: train/945.jpg
#   inflating: train/946.jpg
#   inflating: train/947.jpg
#   inflating: train/948.jpg
#   inflating: train/949.jpg
#   inflating: train/95.jpg
#   inflating: train/950.jpg
#   inflating: train/951.jpg
#   inflating: train/952.jpg
#   inflating: train/953.jpg
#   inflating: train/954.jpg
#   inflating: train/955.jpg
#   inflating: train/956.jpg
#   inflating: train/957.jpg
#   inflating: train/958.jpg
#   inflating: train/959.jpg
#   inflating: train/96.jpg
#   inflating: train/960.jpg
#   inflating: train/961.jpg
#   inflating: train/962.jpg
#   inflating: train/963.jpg
#   inflating: train/964.jpg
#   inflating: train/965.jpg
#   inflating: train/966.jpg
#   inflating: train/967.jpg
#   inflating: train/968.jpg
#   inflating: train/969.jpg
#   inflating: train/97.jpg
#   inflating: train/970.jpg
#   inflating: train/971.jpg
#   inflating: train/972.jpg
#   inflating: train/973.jpg
#   inflating: train/974.jpg
#   inflating: train/975.jpg
#   inflating: train/976.jpg
#   inflating: train/977.jpg
#   inflating: train/978.jpg
#   inflating: train/979.jpg
#   inflating: train/98.jpg
#   inflating: train/980.jpg
#   inflating: train/981.jpg
#   inflating: train/982.jpg
#   inflating: train/983.jpg
#   inflating: train/984.jpg
#   inflating: train/985.jpg
#   inflating: train/986.jpg
#   inflating: train/987.jpg
#   inflating: train/988.jpg
#   inflating: train/989.jpg
#   inflating: train/99.jpg
#   inflating: train/990.jpg
#   inflating: train/991.jpg
#   inflating: train/992.jpg
#   inflating: train/993.jpg
#   inflating: train/994.jpg
#   inflating: train/995.jpg
#   inflating: train/996.jpg
#   inflating: train/997.jpg
#   inflating: train/998.jpg
#   inflating: train/999.jpg

# %% [markdown]
# ### Checking Our Training Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Read the CSV file into a pandas DataFrame
csv_file_path = '/content/train.csv'  # Replace with the path to your CSV file
df = pd.read_csv(csv_file_path)

# Step 2: Group the data by the class column and count the occurrences
class_counts = df['Class'].value_counts() / 481

# Step 3: Plot the class-wise distribution
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.bar(class_counts.index, class_counts.values)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Class-wise Distribution')
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.tight_layout()

# Step 4: Show the plot or save it to a file
plt.show()
mean_without_0=df[df['Class'] != 0].groupby('Class').count().mean()
mean_without_0_1 = df[(df['Class'] != 0) & (df['Class'] != 1)].groupby('Class').count().mean()
class_counts = df.groupby('Class').count()
print(mean_without_0)
print(mean_without_0_1)
print(class_counts)
# Out:
# FileName    481.714286
# dtype: float64
# FileName    327.833333
# dtype: float64
#        FileName
# Class
# 0          4829
# 1          1405
# 2           285
# 3           443
# 4           789
# 5            68
# 6           295
# 7            87

# %% [markdown]
# ### Creating Validation.csv File

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Step 1: Read the CSV file into a pandas DataFrame
csv_file_path = '/content/train.csv'  # Replace with the path to your CSV file
df = pd.read_csv(csv_file_path)

# Step 2: Split the DataFrame into training and validation sets
train_df, val_df = train_test_split(df, test_size=0.1, random_state=42)

# Step 3: Save the training and validation sets to separate CSV files if needed
train_df.to_csv('/content/train_split.csv', index=False)
val_df.to_csv('/content/validation_split.csv', index=False)

# Now, train_df contains your training data, and val_df contains your validation data.

# %% [markdown]
# ### Creating Sampled Data

# %%
# Import pandas library
import pandas as pd

# Load your csv file as a pandas DataFrame
df = pd.read_csv("/content/train_split.csv")

# Filter out the rows that have class 0
df_0 = df[df['Class'] == 0]
# df_1 = df[df['Class'] == 1]
# Randomly sample 600 rows from the filtered DataFrame
df_0_2500 = df_0.sample(n=2500)
remaining_df_0_2500 = df_0.drop(df_0_2500.index)
remaining_df_0_2500 = remaining_df_0_2500.reset_index(drop=True)
# df_1 = df_1.sample (n=600)
# Concatenate the sampled DataFrame with the original DataFrame without class 0
df = pd.concat ([df[df['Class'] != 0], df_0_2500])
remaining_df = pd.concat ([df[df['Class'] != 0], remaining_df_0_2500])
# df = pd.concat ([df[df['Class'] != 1], df_1])
# Reset the index and drop the old one
df = df.reset_index(drop=True)
remaining_df = remaining_df.reset_index(drop=True)

# Save the new DataFrame as a csv file
df.to_csv ("/content/drive/MyDrive/GOD_OF_AI/new_train_2500.csv", index=False)
# Save the new DataFrame as a csv file
remaining_df.to_csv ("/content/drive/MyDrive/GOD_OF_AI/new_remaining_train_2500.csv", index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Read the CSV file into a pandas DataFrame
csv_file_path = '/content/drive/MyDrive/GOD_OF_AI/submissions/submission_split27.csv'  # Replace with the path to your CSV file
df = pd.read_csv(csv_file_path)

# Step 2: Group the data by the class column and count the occurrences
class_counts = df['Class'].value_counts()

# Step 3: Plot the class-wise distribution
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.bar(class_counts.index, class_counts.values)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Class-wise Distribution')
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.tight_layout()

# Step 4: Show the plot or save it to a file
plt.show()
mean_without_0=df[df['Class'] != 0].groupby('Class').count().mean()
mean_without_0_1 = df[(df['Class'] != 0) & (df['Class'] != 1)].groupby('Class').count().mean()
class_counts = df.groupby('Class').count()
print(mean_without_0)
print(mean_without_0_1)
print(class_counts)
# Out:
# FileName    145.571429
# dtype: float64
# FileName    67.833333
# dtype: float64
#        FileName
# Class
# 0          1675
# 1           612
# 2            21
# 3           200
# 4            47
# 5             3
# 6           126
# 7            10

# %% [markdown]
# ### Creating Organized Training Directory

# %%
import pandas as pd
import os
import shutil

# Load the CSV file into a pandas DataFrame
csv_file_path = '/content/drive/MyDrive/GOD_OF_AI/new_train_2500.csv'  # Replace with the path to your CSV file
df = pd.read_csv(csv_file_path)

# Image directory containing your images
image_dir = '/content/train'  # Replace with the path to your image directory

# Create 8 class-specific directories if they don't exist
output_dir_base = '/content/drive/MyDrive/GOD_OF_AI/train_split_directory_2500'
class_labels = df['Class'].unique()
for label in class_labels:
    output_dir = os.path.join(output_dir_base, str(label))
    os.makedirs(output_dir, exist_ok=True)

# Iterate through the DataFrame and move images to the corresponding class-specific directory
for index, row in df.iterrows():
    image_filename = row['FileName']
    class_label = row['Class']
    source_image_path = os.path.join(image_dir, image_filename)
    destination_dir = os.path.join(output_dir_base, str(class_label))
    destination_image_path = os.path.join(destination_dir, image_filename)

    # Move the image to the appropriate directory
    shutil.copy(source_image_path, destination_image_path)

print("Data organization completed.")
# Out:
# Data organization completed.

# %% [markdown]
# * Remaining train split data directory

# %%
import pandas as pd
import os
import shutil

# Load the CSV file into a pandas DataFrame
csv_file_path = '/content/drive/MyDrive/GOD_OF_AI/new_remaining_train_2500.csv'  # Replace with the path to your CSV file
df = pd.read_csv(csv_file_path)

# Image directory containing your images
image_dir = '/content/train'  # Replace with the path to your image directory

# Create 8 class-specific directories if they don't exist
output_dir_base = '/content/drive/MyDrive/GOD_OF_AI/remaining_train_split_directory_2500'
class_labels = df['Class'].unique()
for label in class_labels:
    output_dir = os.path.join(output_dir_base, str(label))
    os.makedirs(output_dir, exist_ok=True)

# Iterate through the DataFrame and move images to the corresponding class-specific directory
for index, row in df.iterrows():
    image_filename = row['FileName']
    class_label = row['Class']
    source_image_path = os.path.join(image_dir, image_filename)
    destination_dir = os.path.join(output_dir_base, str(class_label))
    destination_image_path = os.path.join(destination_dir, image_filename)

    # Move the image to the appropriate directory
    shutil.copy(source_image_path, destination_image_path)

print("Data organization completed.")
# Out:
# Data organization completed.

# %% [markdown]
# * validation directory

# %%
import pandas as pd
import os
import shutil

# Load the CSV file into a pandas DataFrame
csv_file_path = '/content/validation_split.csv'  # Replace with the path to your CSV file
df = pd.read_csv(csv_file_path)

# Image directory containing your images
image_dir = '/content/train'  # Replace with the path to your image directory

# Create 8 class-specific directories if they don't exist
output_dir_base = '/content/drive/MyDrive/GOD_OF_AI/validation_split_directory'
class_labels = df['Class'].unique()
for label in class_labels:
    output_dir = os.path.join(output_dir_base, str(label))
    os.makedirs(output_dir, exist_ok=True)

# Iterate through the DataFrame and move images to the corresponding class-specific directory
for index, row in df.iterrows():
    image_filename = row['FileName']
    class_label = row['Class']
    source_image_path = os.path.join(image_dir, image_filename)
    destination_dir = os.path.join(output_dir_base, str(class_label))
    destination_image_path = os.path.join(destination_dir, image_filename)

    # Move the image to the appropriate directory
    shutil.copy(source_image_path, destination_image_path)

print("Data organization completed.")
# Out:
# Data organization completed.

# %% [markdown]
# ### Creating Dummy Images for classes with less data

# %%
import os
import shutil
import random
import pandas as pd
import numpy as np
from torchvision import transforms
from PIL import Image
import torch
import torchvision
from torch.utils.data import DataLoader, Dataset
import torchvision.models as models

# Define the paths to your original dataset and train directory
original_dataset_path = '/content/drive/MyDrive/GOD_OF_AI/train_directory_500'
train_directory = '/content/drive/MyDrive/GOD_OF_AI/train_directory_500'

# Define the classes for which you want to create dummy images
target_classes = ['5', '7']  # Replace with your specific class names

# Set the number of dummy images to generate per class
num_dummy_images_per_class = 100

# Ensure the train directory exists
if not os.path.exists(train_directory):
    os.makedirs(train_directory)

def get_randaugment_transform(rotatRand, cont, sat, hu, n, m):
    # Define the base transformations without RandAugment
    base_transform = transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(rotatRand),
        transforms.ColorJitter(brightness=0.2, contrast=cont, saturation=sat, hue=hu),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    # Apply RandAugment on top of the base transformations
    randaug_transform = transforms.Compose([
        transforms.RandAugment(n, m),
        base_transform,
    ])

    return randaug_transform

def get_randaugment_bw_transform(rotatRand, n, m):
    # Define the base transformations without RandAugment
    base_transform = transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(rotatRand),
        transforms.Grayscale(num_output_channels=3),  # Convert image to grayscale
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    # Apply RandAugment on top of the base transformations
    randaug_transform = transforms.Compose([
        transforms.RandAugment(n, m),
        base_transform,
    ])

    return randaug_transform

# Function to load an image from the original dataset
def load_image(image_path):
    return Image.open(image_path).convert('RGB')

# Function to generate dummy images with data augmentation
def generate_dummy_images(class_name, num_images):
    class_dir = os.path.join(train_directory, class_name)
    if not os.path.exists(class_dir):
        os.makedirs(class_dir)

    image_files = os.listdir(os.path.join(original_dataset_path, class_name))
    print(image_files)

    rotatRand = random.randint(25, 35)  # Define your rotation angle
    cont = 0.2      # Define your contrast factor
    sat = 0.2       # Define your saturation factor
    hu = 0.2        # Define your hue factor
    n = 2           # Number of transformations to apply
    m = 10          # Magnitude of transformations

    # Get the RandAugment transform
    transform = get_randaugment_bw_transform(rotatRand, n, m)

    for i in range(num_images):
        # Randomly select an existing image
        existing_image_path = os.path.join(original_dataset_path, class_name, random.choice(image_files))
        existing_image = load_image(existing_image_path)

        # Apply the defined transformations to the image
        augmented_image = transform(existing_image)

        # Save the augmented image as a dummy image
        save_path = os.path.join(class_dir, f'dummy{class_name}_{i}.jpg')
        torchvision.utils.save_image(augmented_image, save_path)

# Loop through the target classes
for class_name in target_classes:
    generate_dummy_images(class_name, num_dummy_images_per_class)

# Now you have dummy images for specific classes with data augmentation in the train directory.
# You can use these images for training your image classification model.

# %% [markdown]
# # Classification

# %% [markdown]
# ### Creating DataLoader

# %%
train_dataset_directory = '/content/drive/MyDrive/GOD_OF_AI/train_split_directory_2500'
import torch
import torchvision
from torchvision import transforms

input_shape = (256, 256, 3) # define the input shape
num_classes = 8 # define the number of classes
batch_size = 256 # define the batch size

# define the data augmentation for the training set
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(input_shape[:2]), # randomly crop and resize the images
    transforms.RandomHorizontalFlip(), # randomly flip the images horizontally
    transforms.RandomRotation(20), # randomly rotate the images by 20 degrees
    transforms.RandomVerticalFlip(), # randomly flip the images vertically
    transforms.ToTensor(), # convert the images to tensors
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)) # normalize the images using the mean and standard deviation of ImageNet
])

# create the training dataset from a directory of images
train_dataset = torchvision.datasets.ImageFolder(
    root=train_dataset_directory, # specify the directory of the training images
    transform=train_transform, # apply the data augmentation for the training set
)

# create the data loaders for the training and test sets
train_loader = torch.utils.data.DataLoader(
    train_dataset, # use the training dataset
    batch_size=batch_size, # use the batch size
    shuffle=True, # shuffle the data
)

# %% [markdown]
# ### Creating Model

# %%
import torch
import torch.nn as nn
from torchvision import models

def create_efficientNetV2_model(input_shape, num_classes):
    base_model = models.efficientnet_v2_s(pretrained=False, dropout=0.2) # load the shufflenet_v2_x1_0 model with pretrained weights
    for param in base_model.parameters(): # freeze the parameters of the base model
        param.requires_grad = False

    model = nn.Sequential(
        base_model, # use the feature extractor part of the base model
        nn.Flatten(), # flatten the output of the feature extractor
        nn.Linear(1000, 256), # add a fully connected layer with 256 units
        nn.ReLU(), # add a ReLU activation function
        nn.Linear(256, num_classes), # add a fully connected layer with num_classes units
        nn.Softmax(dim=1) # add a softmax activation function for the output layer
    )
    return model

def create_shufflenet_model(input_shape, num_classes):
    base_model = models.shufflenet_v2_x1_5(pretrained=True) # load the shufflenet_v2_x1_0 model with pretrained weights
    #base_model.features[0] = nn.Conv2d(input_shape[0], 64, kernel_size=2, stride =1 , padding=1) # replace the first convolutional layer to match the input shape
    for param in base_model.parameters(): # freeze the parameters of the base model
        param.requires_grad = False

    model = nn.Sequential(
        base_model, # use the feature extractor part of the base model
        nn.Flatten(), # flatten the output of the feature extractor
        nn.Linear(1000, 256), # add a fully connected layer with 256 units
        nn.ReLU(), # add a ReLU activation function
        nn.Linear(256, num_classes), # add a fully connected layer with num_classes units
        nn.Softmax(dim=1) # add a softmax activation function for the output layer
    )
    return model

def create_mobilenet_model(input_shape, num_classes):
    base_model = models.mobilenet_v3_large(pretrained=False)
    for param in base_model.parameters(): # freeze the parameters of the base model
        param.requires_grad = False

    model = nn.Sequential(
        base_model, # use the feature extractor part of the base model
        nn.Flatten(), # flatten the output of the feature extractor
        nn.Linear(1000, 256), # add a fully connected layer with 256 units
        nn.ReLU(), # add a ReLU activation function
        nn.Linear(256, num_classes), # add a fully connected layer with num_classes units
        nn.Softmax(dim=1) # add a softmax activation function for the output layer
    )
    return model

# %% [markdown]
# * Custom model

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class CustomCNN(nn.Module):
    def __init__(self, input_shape, num_classes, filter_size_1, filter_size_2, filter_size_3, stride_1):
        super(CustomCNN, self).__init__()

        # Convolutional layers
        layer_1_filtersize = filter_size_1
        if layer_1_filtersize == (11, 11):
            possible_strides = [1, 2, 4]
        else:
            possible_strides = [1, 2]
        self.conv1 = nn.Conv2d(input_shape[0], 128, layer_1_filtersize, stride=stride_1)
        self.pool = nn.MaxPool2d(2, 2)

        # Additional convolutional layers
        self.conv_layers = nn.ModuleList()
        for filter_size in [filter_size_2, filter_size_3]:
            self.conv_layers.append(nn.Conv2d(128, 128, filter_size))

        # Fully connected layers

        self.fc_layers = nn.ModuleList()
        self.fc_layers.append(nn.Linear(93312, 512))
        for _ in range(4):  # Use 4 dense layers as in your original code
            self.fc_layers.append(nn.Linear(512, 512))
            self.fc_layers.append(nn.ReLU())
            self.fc_layers.append(nn.Dropout(0.5))

        # Output softmax layer
        self.fc_out = nn.Linear(512, num_classes)

    def forward(self, x):
        x = nn.functional.relu(self.conv1(x))
        x = self.pool(x)

        for conv_layer in self.conv_layers:
            x = nn.functional.relu(conv_layer(x))

        x = self.pool(x)
        x = x.view(x.size(0), -1)

        for layer in self.fc_layers:
            x = layer(x)

        x = self.fc_out(x)
        return x

# Example usage:
input_shape = (3, 224, 224)  # Example input shape for RGB images
num_classes = 8 # Example number of classes
filter_size_1 = (11, 11)
filter_size_2 = (3, 3)
filter_size_3 = (5, 5)
stride_1 = 2
# learning_rate = 0.0001
# optimizer = 'rmsprop'



# Create DataLoader and train the model
# Define your DataLoader and training loop accordingly

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class CosineLoss(nn.Module):
    def __init__(self, xent=.1, reduction="mean"):
        super(CosineLoss, self).__init__()
        self.xent = xent
        self.reduction = reduction

        self.y = torch.Tensor([1]).cuda()

    def forward(self, input, target):
        cosine_loss = F.cosine_embedding_loss(input, F.one_hot(target, num_classes=input.size(-1)), self.y, reduction=self.reduction)
        cent_loss = F.cross_entropy(F.normalize(input), target, reduction=self.reduction)

        return cosine_loss + self.xent * cent_loss

class FocalCosineLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, xent=.1, reduction="mean"):
        super(FocalCosineLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

        self.xent = xent
        self.reduction = reduction

        self.y = torch.Tensor([1])

    def forward(self, input, target):
        cosine_loss = F.cosine_embedding_loss(input, F.one_hot(target, num_classes=input.size(-1)), self.y, reduction=self.reduction)

        cent_loss = F.cross_entropy(F.normalize(input), target, reduce=False)
        pt = torch.exp(-cent_loss)
        focal_loss = self.alpha * (1-pt)**self.gamma * cent_loss

        if self.reduction == "mean":
            focal_loss = torch.mean(focal_loss)

        return cosine_loss + self.xent * focal_loss

# %% [markdown]
# Focal loss for multiclassification

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class FocalLoss(nn.Module):
    def __init__(self, gamma=2, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        # Compute cross-entropy loss
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')

        # Compute the class probabilities
        probs = torch.exp(-ce_loss)

        # Compute the frequency of each class in the batch
        class_counts = torch.bincount(targets)

        # Compute the alpha values based on class frequencies
        alpha = 1 / (class_counts + 1e-8)  # Adding a small epsilon to prevent division by zero

        # Gather the alpha values for the target classes
        alpha = alpha[targets]

        # Compute the focal loss
        focal_loss = (alpha * (1 - probs) ** self.gamma * ce_loss)

        # Apply reduction
        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %%
# !pip install torchmetrics

# %% [markdown]
# * Traininig with warmup epochs

# %%
# @title
epochs = 100
warmup_epochs = 5  # Number of warm-up epochs
desired_lr = 0.001  # Desired learning rate after warm-up
initial_lr = 0.001  # Initial learning rate for warm-up

save_dir = '/content/drive/MyDrive/GOD_OF_AI/mobilenet_wts'
import os
import torch
import torchmetrics
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import MultiStepLR

model = create_mobilenet_model(input_shape, num_classes)
model.load_state_dict(torch.load('/content/drive/MyDrive/GOD_OF_AI/mobilenet_wts/mobilenet_wts_split2500_epoch109.pt'))
optimizer = optim.Adam(model.parameters(), lr=0.001)
# loss_fn = nn.CrossEntropyLoss()
loss_fn = FocalCosineLoss()
# Create an instance of the MulticlassF1Score metric
f1 = torchmetrics.classification.MulticlassF1Score(num_classes=num_classes, average='macro')
# Create a learning rate scheduler
scheduler = MultiStepLR(optimizer, milestones=[50], gamma=0.95)

# Warm-up phase
for epoch in range(warmup_epochs):
    total_correct = 0
    total_samples = 0
    f1.reset()
    for images, labels in train_loader:
        optimizer.zero_grad()
        images = images.permute(0, 1, 3, 2)
        predictions = model(images)
        loss = loss_fn(predictions, labels)
        loss.backward()
        optimizer.step()
        pred_labels = torch.argmax(predictions, dim=1)
        labels = labels.to(torch.int64)
        total_correct += torch.sum(pred_labels == labels)
        total_samples += labels.shape[0]
        f1.update(pred_labels, labels)
    train_acc = total_correct / total_samples
    train_f1 = f1.compute()

    # Linearly increase the learning rate during warm-up
    current_lr = initial_lr + (desired_lr - initial_lr) * (epoch / warmup_epochs)
    for param_group in optimizer.param_groups:
        param_group['lr'] = current_lr
    warmup_text = f"Warm_Up_Epoch {epoch+1}/{warmup_epochs}, Loss: {loss.item()}, Train accuracy: {train_acc}, Train macro F1 score: {train_f1}, Learning Rate: {current_lr}"
    print(warmup_text)
    file_path = "/content/drive/MyDrive/GOD_OF_AI/mobilenet_remaining.txt"

    # Open the file in write mode and write the text
    with open(file_path, "a") as file:
        file.write(warmup_text + '\n')

# Training phase after warm-up
for epoch in range(warmup_epochs, epochs):
    total_correct = 0
    total_samples = 0
    f1.reset()
    for images, labels in train_loader:
        optimizer.zero_grad()
        images = images.permute(0, 1, 3, 2)
        predictions = model(images)
        loss = loss_fn(predictions, labels)
        loss.backward()
        optimizer.step()
        pred_labels = torch.argmax(predictions, dim=1)
        labels = labels.to(torch.int64)
        total_correct += torch.sum(pred_labels == labels)
        total_samples += labels.shape[0]
        f1.update(pred_labels, labels)
    train_acc = total_correct / total_samples
    train_f1 = f1.compute()
    scheduler.step()

    save_path = os.path.join(save_dir, f'mobilenet_wts_remaining_epoch{epoch}.pt')
    torch.save(model.state_dict(), save_path)

    text_to_print = f"Epoch {epoch+1}/{epochs}, Loss: {loss.item()}, Train accuracy: {train_acc}, Train macro F1 score: {train_f1}, Learning Rate: {scheduler.get_last_lr()}"

    print(text_to_print)

    # Define the text you want to print to the file

    # Specify the file path where you want to save the text
    file_path = "/content/drive/MyDrive/GOD_OF_AI/mobilenet_remaining.txt"

    # Open the file in write mode and write the text
    with open(file_path, "a") as file:
        file.write(text_to_print + '\n')

# %% [markdown]
# * Training without warm epochs.

# %%
epochs = 150
save_dir = '/content/drive/MyDrive/GOD_OF_AI/customCNN_wts'
import os
import torch
import torchmetrics
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import MultiStepLR

# model = create_shufflenet_model(input_shape, num_classes)
model = CustomCNN(input_shape, num_classes, filter_size_1, filter_size_2, filter_size_3, stride_1)
# model.load_state_dict(torch.load('/content/drive/MyDrive/GOD_OF_AI/mobilenet_wts/mobilenet_wts_split2500_epoch13.pt'))
optimizer = optim.RMSprop(model.parameters(), lr=0.0001)
loss_fn = nn.CrossEntropyLoss()
#loss_fn = FocalCosineLoss()


scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=1e-6)

# Create an instance of the MulticlassF1Score metric
f1 = torchmetrics.classification.MulticlassF1Score(num_classes=num_classes, average='macro')

# Train the shufflenetV2 model on the resampled data
for epoch in range(epochs):
    total_correct = 0
    total_samples = 0
    f1.reset()
    for images, labels in train_loader: #r
        optimizer.zero_grad() # zero out the gradients
        images = images.permute(0, 1, 3, 2)
        predictions = model(images) # get the model predictions
        loss = loss_fn(predictions, labels) # compute the loss
        # loss = loss1 + loss_fn2(predictions, labels)
        loss.backward()
        optimizer.step() # update the model parameters
        pred_labels = torch.argmax(predictions, dim=1) # get the predicted labels from the predictions
        labels = labels.to(torch.int64) # cast the true labels to int64 type
        total_correct += torch.sum(pred_labels == labels) # count the number of correct predictions
        total_samples += labels.shape[0] # count the number of samples
        f1.update(pred_labels, labels) # update the metric with the predicted and true labels
    train_acc = total_correct / total_samples # compute the train accuracy
    train_f1 = f1.compute() # compute the macro F1 score at the end of each epoch
    # Step the learning rate scheduler at the end of each epoch

    scheduler.step()

    save_path = os.path.join(save_dir, f'customCNN_epoch{epoch}.pt')
    torch.save(model.state_dict(), save_path)

    text_to_print = f"Epoch {epoch+1}/{epochs}, Loss: {loss.item()}, Train accuracy: {train_acc}, Train macro F1 score: {train_f1}, Learning Rate: {scheduler.get_last_lr()}"

    print(text_to_print)

    # Define the text you want to print to the file

    # Specify the file path where you want to save the text
    file_path = "/content/drive/MyDrive/GOD_OF_AI/customCNN.txt"

    # Open the file in write mode and write the text
    with open(file_path, "a") as file:
        file.write(text_to_print + '\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3eff44a14437> in <cell line: 11>()
#       9
#      10 # model = create_shufflenet_model(input_shape, num_classes)
# ---> 11 model = CustomCNN(input_shape, num_classes, filter_size_1, filter_size_2, filter_size_3, stride_1)
#      12 # model.load_state_dict(torch.load('/content/drive/MyDrive/GOD_OF_AI/mobilenet_wts/mobilenet_wts_split2500_epoch13.pt'))
#      13 optimizer = optim.RMSprop(model.parameters(), lr=0.0001)
#
# NameError: name 'CustomCNN' is not defined

# %% [markdown]
# ### submission.csv file generator

# %%
#!unzip /content/drive/MyDrive/ai-of-god-v20.zip
import torch
import torch.nn as nn
from torchvision import models, transforms
import pandas as pd
import numpy as np
from torch.autograd import Variable
from PIL import Image
import os
input_shape = (256, 256, 3) # define the input shape
num_classes = 8 # define the number of classes
batch_size = 16 # define the batch size

# define the data augmentation for the training set
transform = transforms.Compose([
    transforms.RandomResizedCrop(input_shape[:2]), # randomly crop and resize the images
    transforms.RandomHorizontalFlip(), # randomly flip the images horizontally
    transforms.RandomRotation(20), # randomly rotate the images by 20 degrees
    transforms.RandomVerticalFlip(), # randomly flip the images vertically
    transforms.ToTensor() # normalize the images using the mean and standard deviation of ImageNet
])

normalize = transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
def create_shufflenet_model(input_shape, num_classes):
    base_model = models.shufflenet_v2_x0_5(pretrained=False) # load the shufflenet_v2_x1_0 model with pretrained weights
    #base_model.features[0] = nn.Conv2d(input_shape[0], 64, kernel_size=2, stride =1 , padding=1) # replace the first convolutional layer to match the input shape
    for param in base_model.parameters(): # freeze the parameters of the base model
        param.requires_grad = False

    model = nn.Sequential(
        base_model, # use the feature extractor part of the base model
        nn.Flatten(), # flatten the output of the feature extractor
        nn.Linear(1000, 256), # add a fully connected layer with 256 units
        nn.ReLU(), # add a ReLU activation function
        nn.Linear(256, num_classes), # add a fully connected layer with num_classes units
        nn.Softmax(dim=1) # add a softmax activation function for the output layer
    )
    return model

def create_efficientNetV2_model(input_shape, num_classes):
    base_model = models.efficientnet_v2_s(pretrained=False) # load the shufflenet_v2_x1_0 model with pretrained weights
    for param in base_model.parameters(): # freeze the parameters of the base model
        param.requires_grad = False

    model = nn.Sequential(
        base_model, # use the feature extractor part of the base model
        nn.Flatten(), # flatten the output of the feature extractor
        nn.Linear(1000, 256), # add a fully connected layer with 256 units
        nn.ReLU(), # add a ReLU activation function
        nn.Linear(256, num_classes), # add a fully connected layer with num_classes units
        nn.Softmax(dim=1) # add a softmax activation function for the output layer
    )
    return model

# Define the transformation for input images (modify as needed)


# Load the custom model
input_shape = (3,256,256) # define the input shape
num_classes = 8 # define the number of classes
model = create_shufflenet_model(input_shape, num_classes)
model.load_state_dict(torch.load('/content/drive/MyDrive/AOG_Rerun_wts/model_split_weights_epoch_27.pt'))
model.eval()

# Load the CSV file containing image file paths
image_df = pd.read_csv('/content/test.csv')

# Create empty lists to store image names and classes
image_names = []
image_classes = []
root_directory = '/content/test'  # Replace with your actual root directory path
# Loop through each row in the CSV file
for index, row in image_df.iterrows():
    image_path = row['FileName']  # Assuming your CSV has a column named 'image_path'
    image_path = os.path.join(root_directory, image_path)
    image = Image.open(image_path)
    dummy_image = transform(image).expand(3,-1,-1)
    dummy_image= normalize(dummy_image)
    dummy_image = Variable(dummy_image.unsqueeze(0))

    # Predict the class of the image
    with torch.no_grad():
        output = model(dummy_image)
        predicted_class = torch.argmax(output).item()

    # Append image name and predicted class to lists
    image_names.append(row['FileName'])  # Assuming your CSV has a column named 'image_name'
    image_classes.append(predicted_class)

# Create a new DataFrame with image names and predicted classes
result_df = pd.DataFrame({'FileName': image_names, 'Class': image_classes})

# Save the result to a new CSV file
result_df.to_csv('/content/drive/MyDrive/GOD_OF_AI/submissions/submission_split27.csv', index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %% [markdown]
# * submission.csv from 2 weight files

# %%
#!unzip /content/drive/MyDrive/ai-of-god-v20.zip
import torch
import torch.nn as nn
from torchvision import models, transforms
import pandas as pd
import numpy as np
from torch.autograd import Variable
from PIL import Image
import os
input_shape = (256, 256, 3) # define the input shape
num_classes = 8 # define the number of classes
batch_size = 16 # define the batch size

# define the data augmentation for the training set
transform = transforms.Compose([
    transforms.RandomResizedCrop(input_shape[:2]), # randomly crop and resize the images
    transforms.RandomHorizontalFlip(), # randomly flip the images horizontally
    transforms.RandomRotation(20), # randomly rotate the images by 20 degrees
    transforms.RandomVerticalFlip(), # randomly flip the images vertically
    transforms.ToTensor() # normalize the images using the mean and standard deviation of ImageNet
])

normalize = transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
def create_shufflenet_model(input_shape, num_classes):
    base_model = models.shufflenet_v2_x0_5(pretrained=False) # load the shufflenet_v2_x1_0 model with pretrained weights
    #base_model.features[0] = nn.Conv2d(input_shape[0], 64, kernel_size=2, stride =1 , padding=1) # replace the first convolutional layer to match the input shape
    for param in base_model.parameters(): # freeze the parameters of the base model
        param.requires_grad = False

    model = nn.Sequential(
        base_model, # use the feature extractor part of the base model
        nn.Flatten(), # flatten the output of the feature extractor
        nn.Linear(1000, 256), # add a fully connected layer with 256 units
        nn.ReLU(), # add a ReLU activation function
        nn.Linear(256, num_classes), # add a fully connected layer with num_classes units
        nn.Softmax(dim=1) # add a softmax activation function for the output layer
    )
    return model

def create_efficientNet_model(input_shape, num_classes):
    base_model = models.efficientnet_b3(pretrained=False) # load the shufflenet_v2_x1_0 model with pretrained weights
    for param in base_model.parameters(): # freeze the parameters of the base model
        param.requires_grad = False

    model = nn.Sequential(
        base_model, # use the feature extractor part of the base model
        nn.Flatten(), # flatten the output of the feature extractor
        nn.Linear(1000, 256), # add a fully connected layer with 256 units
        nn.ReLU(), # add a ReLU activation function
        nn.Linear(256, num_classes), # add a fully connected layer with num_classes units
        nn.Softmax(dim=1) # add a softmax activation function for the output layer
    )
    return model
def create_mobilenet_model(input_shape, num_classes):
    base_model = models.mobilenet_v3_large(pretrained=False) # load the shufflenet_v2_x1_0 model with pretrained weights
    for param in base_model.parameters(): # freeze the parameters of the base model
        param.requires_grad = False

    model = nn.Sequential(
        base_model, # use the feature extractor part of the base model
        nn.Flatten(), # flatten the output of the feature extractor
        nn.Linear(1000, 256), # add a fully connected layer with 256 units
        nn.ReLU(), # add a ReLU activation function
        nn.Linear(256, num_classes), # add a fully connected layer with num_classes units
        nn.Softmax(dim=1) # add a softmax activation function for the output layer
    )
    return model
# Define the transformation for input images (modify as needed)


# Load the custom model
input_shape = (3,256,256) # define the input shape
num_classes = 8 # define the number of classes
model1 = create_shufflenet_model(input_shape, num_classes)
model1.load_state_dict(torch.load('/content/drive/MyDrive/AOG_Rerun_wts/model_split_weights_epoch_8.pt'))
model1.eval()

model2 = create_mobilenet_model(input_shape, num_classes)
model2.load_state_dict(torch.load('/content/drive/MyDrive/GOD_OF_AI/mobilenet_wts/mobilenet_wts_split2500_epoch46.pt'))
model2.eval()
# Load the CSV file containing image file paths
image_df = pd.read_csv('/content/test.csv')

# Create empty lists to store image names and classes
image_names = []
image_classes = []
root_directory = '/content/test'  # Replace with your actual root directory path
# Loop through each row in the CSV file
for index, row in image_df.iterrows():
    image_path = row['FileName']  # Assuming your CSV has a column named 'image_path'
    image_path = os.path.join(root_directory, image_path)
    image = Image.open(image_path)
    dummy_image = transform(image).expand(3,-1,-1)
    dummy_image= normalize(dummy_image)
    dummy_image = Variable(dummy_image.unsqueeze(0))

    # Predict the class of the image
    with torch.no_grad():
      output1 = model1(dummy_image)
      output2 = model2(dummy_image)

      predicted_class1 = torch.argmax(output1).item()
      predicted_class2 = torch.argmax(output2).item()
      # print(predicted_class1)
      # print(predicted_class2)

      if output1[0][predicted_class1] > output2[0][predicted_class2]:
          predicted_class = predicted_class1
      else:
          predicted_class = predicted_class2

    # Append image name and predicted class to lists
    image_names.append(row['FileName'])  # Assuming your CSV has a column named 'image_name'
    image_classes.append(predicted_class)

# Create a new DataFrame with image names and predicted classes
result_df = pd.DataFrame({'FileName': image_names, 'Class': image_classes})

# Save the result to a new CSV file
result_df.to_csv('/content/submission.csv', index=False)

# %% [markdown]
# ### Ensemble Method

# %%
import torch
import torch.nn as nn
import numpy as np

# Define your model architecture
class YourModel(nn.Module):
    def __init__(self, input_size, num_classes):
        super(YourModel, self).__init__()
        # Define your model layers here

    def forward(self, x):
        # Define the forward pass of your model

# Load your pre-trained models
model_all_classes = YourModel(input_size, num_classes=8)
model_all_classes.load_state_dict(torch.load('model_all_classes.pth'))
model_all_classes.eval()  # Set the model to evaluation mode

model_1_to_6_classes = YourModel(input_size, num_classes=6)
model_1_to_6_classes.load_state_dict(torch.load('model_1_to_6_classes.pth'))
model_1_to_6_classes.eval()  # Set the model to evaluation mode

# Load and preprocess your input data
input_data = torch.tensor(your_input_data, dtype=torch.float32)

# Make predictions using both models
with torch.no_grad():
    predictions_all_classes = model_all_classes(input_data)
    predictions_1_to_6_classes = model_1_to_6_classes(input_data)

# Combine predictions using a weighted average
weight_for_all_classes = 0.5  # You can adjust the weights as needed
weight_for_1_to_6_classes = 0.5

ensemble_predictions = (
    weight_for_all_classes * predictions_all_classes +
    weight_for_1_to_6_classes * predictions_1_to_6_classes
)

# Get the class with the highest probability as the final prediction
final_predictions = ensemble_predictions.argmax(dim=1)

# final_predictions now contains the ensemble's predictions.
